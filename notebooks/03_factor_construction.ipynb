# %% [markdown]
# # 03 Factor Construction
#
# Purpose: construct size, value, momentum, and low-volatility factors across each benchmark universe.
#
# Main tasks:
#
# 1. Load monthly stock-level panel.
# 2. Apply universe-specific filters.
# 3. Sort stocks into factor buckets.
# 4. Construct long-short factor returns.
# 5. Save factor-return files to `outputs/factor_returns/`.
