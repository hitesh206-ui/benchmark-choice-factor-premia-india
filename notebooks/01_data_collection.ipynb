# %% [markdown]
# # 01 Data Collection
#
# Purpose: collect and document public data needed for the benchmark-choice factor premia project.
#
# Main tasks:
#
# 1. Identify public NSE price-volume sources.
# 2. Collect index and benchmark universe information.
# 3. Collect or reconstruct monthly stock universe files.
# 4. Document all URLs, download dates, and limitations.
# 5. Save raw files locally in `data/raw/`.
#
# Raw data files should not be committed to GitHub.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DIR = PROJECT_ROOT / 'data' / 'raw'
RAW_DIR.mkdir(parents=True, exist_ok=True)
RAW_DIR
