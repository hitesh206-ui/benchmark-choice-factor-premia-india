# %% [markdown]
# # 04 Results Analysis
#
# Purpose: compare factor premia across benchmark universes.
#
# Main tasks:
#
# 1. Load factor-return files.
# 2. Calculate performance statistics.
# 3. Compare factor premia by universe.
# 4. Generate tables and figures.
# 5. Export outputs to `outputs/tables/` and `outputs/figures/`.
