# %% [markdown]
# # 02 Data Cleaning
#
# Purpose: convert raw public data into a clean monthly stock-level research panel.
#
# Main tasks:
#
# 1. Standardize symbols and company names.
# 2. Parse dates and convert daily data to monthly observations.
# 3. Calculate returns and liquidity measures.
# 4. Merge universe membership, market cap, and factor signals.
# 5. Save cleaned panel to `data/processed/`.
