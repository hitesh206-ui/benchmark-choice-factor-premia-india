# %% [markdown]
# # 05 Robustness Checks
#
# Purpose: test whether the benchmark-choice results survive alternative assumptions.
#
# Main checks:
#
# 1. Equal-weighted versus value-weighted portfolios.
# 2. Alternative momentum lookback windows.
# 3. Alternative volatility lookback windows.
# 4. Stricter liquidity filters.
# 5. Exclusion of COVID-19 crisis months.
# 6. Alternative universe definitions.
